# %%
import os

import pandas as pd

# %%
DATA_PATH = os.path.join("..", "data", "01_raw", "google_analytics.xlsx")


df = pd.read_excel(DATA_PATH)
print(df.shape)
df.head()
# Out:
# (27, 12)
#         id                               identifier  \
# 0  1435040  SP.c7132f4d-43c3-4375-89e7-b51648d45eab
# 1  1435071  SP.9f2d6820-7fa0-458d-bbe5-a1867805a23a
# 2  1435031  SP.574ef1be-bf23-4f67-9601-ca3ffd6eb586
# 3  1435043  SP.ad7b6bc7-5c90-4df8-89ea-c4ad2d40e580
# 4  1434993  SP.3c70a3cb-1385-43f7-9cb5-87db2f0ded2b
#
#                                        Content.Name  \
# 0           Breast Screening Subsidies in Singapore
# 1                   Marriage and Parenthood Schemes
# 2  Hospital Bills Financial Assistance in Singapore
# 3   Community Health Assist Scheme (CHAS) Singapore
# 4                                          MediSave
#
#                             CostAndFinancing_FullUrl  \
# 0  https://www.healthhub.sg/a-z/costs-and-financi...
# 1  https://www.healthhub.sg/a-z/costs-and-financi...
# 2  https://www.healthhub.sg/a-z/costs-and-financi...
# 3  https://www.healthhub.sg/a-z/costs-and-financi...
# 4  https://www.healthhub.sg/a-z/costs-and-financi...
#
#                                            page path  Page Views  \
# 0  /a-z/costs-and-financing/breast-cancer-screeni...       19647
# 1  /a-z/costs-and-financing/marriage_parenthood_s...       10173
# 2  /a-z/costs-and-financing/financial-assistance-...        6209
# 3                      /a-z/costs-and-financing/chas        6057
# 4                  /a-z/costs-and-financing/medisave        5910
#
#    Engagement Rate  Bounce Rate  Exit Rate  Scroll %  % of Total Views  \
# 0         0.790040     0.209960   0.596020  0.411437          0.207367
# 1         0.725810     0.274190   0.780104  0.394795          0.107372
# 2         0.788974     0.211026   0.686906  0.422532          0.065534
# 3         0.775782     0.224218   0.665016  0.405977          0.063929
# 4         0.751147     0.248853   0.576481  0.352073          0.062378
#
#    Cumulative % of Total Views
# 0                     0.207367
# 1                     0.314740
# 2                     0.380273
# 3                     0.444203
# 4                     0.506581

# %% [markdown]
# ## Standardize column names

# %%
column_names = [
    "id",
    "identifier",
    "content_name",
    "cost_and_financial_full_url",
    "page_path",
    "page_views",
    "engagement_rate",
    "bounce_rate",
    "exit_rate",
    "scroll_perc",
    "perc_of_total_views",
    "cumul_perc_of_total_views",
]

df.columns = column_names
df.head()
# Out:
#         id                               identifier  \
# 0  1435040  SP.c7132f4d-43c3-4375-89e7-b51648d45eab
# 1  1435071  SP.9f2d6820-7fa0-458d-bbe5-a1867805a23a
# 2  1435031  SP.574ef1be-bf23-4f67-9601-ca3ffd6eb586
# 3  1435043  SP.ad7b6bc7-5c90-4df8-89ea-c4ad2d40e580
# 4  1434993  SP.3c70a3cb-1385-43f7-9cb5-87db2f0ded2b
#
#                                        content_name  \
# 0           Breast Screening Subsidies in Singapore
# 1                   Marriage and Parenthood Schemes
# 2  Hospital Bills Financial Assistance in Singapore
# 3   Community Health Assist Scheme (CHAS) Singapore
# 4                                          MediSave
#
#                          cost_and_financial_full_url  \
# 0  https://www.healthhub.sg/a-z/costs-and-financi...
# 1  https://www.healthhub.sg/a-z/costs-and-financi...
# 2  https://www.healthhub.sg/a-z/costs-and-financi...
# 3  https://www.healthhub.sg/a-z/costs-and-financi...
# 4  https://www.healthhub.sg/a-z/costs-and-financi...
#
#                                            page_path  page_views  \
# 0  /a-z/costs-and-financing/breast-cancer-screeni...       19647
# 1  /a-z/costs-and-financing/marriage_parenthood_s...       10173
# 2  /a-z/costs-and-financing/financial-assistance-...        6209
# 3                      /a-z/costs-and-financing/chas        6057
# 4                  /a-z/costs-and-financing/medisave        5910
#
#    engagement_rate  bounce_rate  exit_rate  scroll_perc  perc_of_total_views  \
# 0         0.790040     0.209960   0.596020     0.411437             0.207367
# 1         0.725810     0.274190   0.780104     0.394795             0.107372
# 2         0.788974     0.211026   0.686906     0.422532             0.065534
# 3         0.775782     0.224218   0.665016     0.405977             0.063929
# 4         0.751147     0.248853   0.576481     0.352073             0.062378
#
#    cumul_perc_of_total_views
# 0                   0.207367
# 1                   0.314740
# 2                   0.380273
# 3                   0.444203
# 4                   0.506581

# %%
# Overwrite the raw data
df.to_excel(DATA_PATH, index=False)

# %% [markdown]
# ## Check the data

# %%
DATA_PATH = os.path.join("..", "data", "01_raw", "google_analytics.xlsx")


df = pd.read_excel(DATA_PATH)
print(df.shape)
df.head()
# Out:
# (27, 12)
#         id                               identifier  \
# 0  1435040  SP.c7132f4d-43c3-4375-89e7-b51648d45eab
# 1  1435071  SP.9f2d6820-7fa0-458d-bbe5-a1867805a23a
# 2  1435031  SP.574ef1be-bf23-4f67-9601-ca3ffd6eb586
# 3  1435043  SP.ad7b6bc7-5c90-4df8-89ea-c4ad2d40e580
# 4  1434993  SP.3c70a3cb-1385-43f7-9cb5-87db2f0ded2b
#
#                                        content_name  \
# 0           Breast Screening Subsidies in Singapore
# 1                   Marriage and Parenthood Schemes
# 2  Hospital Bills Financial Assistance in Singapore
# 3   Community Health Assist Scheme (CHAS) Singapore
# 4                                          MediSave
#
#                          cost_and_financial_full_url  \
# 0  https://www.healthhub.sg/a-z/costs-and-financi...
# 1  https://www.healthhub.sg/a-z/costs-and-financi...
# 2  https://www.healthhub.sg/a-z/costs-and-financi...
# 3  https://www.healthhub.sg/a-z/costs-and-financi...
# 4  https://www.healthhub.sg/a-z/costs-and-financi...
#
#                                            page_path  page_views  \
# 0  /a-z/costs-and-financing/breast-cancer-screeni...       19647
# 1  /a-z/costs-and-financing/marriage_parenthood_s...       10173
# 2  /a-z/costs-and-financing/financial-assistance-...        6209
# 3                      /a-z/costs-and-financing/chas        6057
# 4                  /a-z/costs-and-financing/medisave        5910
#
#    engagement_rate  bounce_rate  exit_rate  scroll_perc  perc_of_total_views  \
# 0         0.790040     0.209960   0.596020     0.411437             0.207367
# 1         0.725810     0.274190   0.780104     0.394795             0.107372
# 2         0.788974     0.211026   0.686906     0.422532             0.065534
# 3         0.775782     0.224218   0.665016     0.405977             0.063929
# 4         0.751147     0.248853   0.576481     0.352073             0.062378
#
#    cumul_perc_of_total_views
# 0                   0.207367
# 1                   0.314740
# 2                   0.380273
# 3                   0.444203
# 4                   0.506581
